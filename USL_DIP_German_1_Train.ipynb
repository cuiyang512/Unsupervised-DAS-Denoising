# %%
import os
import time
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras import optimizers, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from keras.layers import *
from keras.utils import Sequence
from keras.optimizers import Adam
import tensorflow.keras.backend as K
from numpy.random import seed

from utils import *
from model import *

# Define paths for figures and models
fig_path = "./figs/German/"
model_path = "./model/"

# Create directories if they do not exist
os.makedirs(fig_path, exist_ok=True)
os.makedirs(model_path, exist_ok=True)
# Out:
# 2024-12-18 10:02:16.007901: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-18 10:02:16.007930: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-18 10:02:16.008988: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-18 10:02:16.013916: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-18 10:02:16.527966: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Data and patch parameters
w1, w2 = 24, 24  # Patch dimensions
z1, z2 = 6, 6    # Patch strides
batch = 1024     # Batch size
drop_rate = 0.2  # Drop rate for patch selection


file_path = './data/'
file_name = 'slice_german_1'

data = np.load(f'{file_path}{file_name}.npy')
data = data[:, :650]

## visual
plt.imshow(data, cmap='seismic', vmin=-0.1, vmax=.1)
plt.title('Loaded Data')
plt.colorbar()
plt.show()

## 2D patching
data_noise = yc_patch(data, w1, w2, z1, z2)

# Patch selection based on kurtosis
data_noise_selected = remove_columns_kurtosis(data_noise, drop_rate)
print(f"Data shape after patching: {data_noise.shape}")
print(f"Data shape after patch selection: {data_noise_selected.shape}")
# Out:
# Data shape after patching: (35086, 576)
# Data shape after patch selection: (28068, 576)

# %%
# Define model parameters
D1 = 128
D2 = D1 // 4  # 32
D3 = D2 // 4  # 8
D4 = D3 // 2  # 2
print(f"Model parameters: D1={D1}, D2={D2}, D3={D3}, D4={D4}")

kernel_size = 3

# Define input sizes
INPUT_SIZE1 = data_noise.shape[0]
INPUT_SIZE2 = data_noise.shape[1]

# Model Input
input_img = Input(shape=(INPUT_SIZE2,))
input_img_expanded = input_img[:, tf.newaxis]

# Encoder
# Level 1
encoded1 = Conv1D(filters=D1, kernel_size=kernel_size, padding='same', name='e1')(input_img_expanded)
encoded1 = BatchNormalization()(encoded1)
encoded1 = PReLU()(encoded1)

encoded1x = Conv1D(filters=D1, kernel_size=kernel_size + 3, padding='same', name='e11')(input_img_expanded)
encoded1x = PReLU()(encoded1x)
encoded1x = concatenate([encoded1x, encoded1], axis=-1)
encoded1x = Dense(D1)(encoded1x)
encoded1x = PReLU()(encoded1x)

skip1 = eca_block(encoded1x)

# Level 2
encoded2 = Conv1D(filters=D2, kernel_size=kernel_size, padding='same', name='e2')(encoded1x)
encoded2 = BatchNormalization()(encoded2)
encoded2 = PReLU()(encoded2)

encoded2x = Conv1D(filters=D2, kernel_size=kernel_size + 3, padding='same', name='e22')(encoded1x)
encoded2x = PReLU()(encoded2x)
encoded2x = concatenate([encoded2x, encoded2], axis=-1)
encoded2x = Dense(D2)(encoded2x)
encoded2x = PReLU()(encoded2x)

skip2 = eca_block(encoded2x)

# Level 3
encoded3 = Conv1D(filters=D3, kernel_size=kernel_size, padding='same', name='e3')(encoded2x)
encoded3 = BatchNormalization()(encoded3)
encoded3 = PReLU()(encoded3)

encoded3x = Conv1D(filters=D3, kernel_size=kernel_size + 3, padding='same', name='e33')(encoded2x)
encoded3x = PReLU()(encoded3x)
encoded3x = concatenate([encoded3x, encoded3], axis=-1)
encoded3x = Dense(D3)(encoded3x)
encoded3x = PReLU()(encoded3x)

skip3 = eca_block(encoded3x)

# Decoder
# Level 3
decoded3 = Conv1D(filters=D3, kernel_size=kernel_size, padding='same', name='d3')(encoded3x)
decoded3 = BatchNormalization()(decoded3)
decoded3 = PReLU()(decoded3)

decoded3x = Conv1D(filters=D3, kernel_size=kernel_size + 3, padding='same', name='d33')(encoded3x)
decoded3x = PReLU()(decoded3x)
decoded3x = concatenate([decoded3x, decoded3], axis=-1)
decoded3x = Dense(D3)(decoded3x)
decoded3x = PReLU()(decoded3x)

decoded3_combined = concatenate([decoded3x, skip3])

# Level 2
decoded2 = Conv1D(filters=D2, kernel_size=kernel_size, padding='same', name='d2')(decoded3_combined)
decoded2 = BatchNormalization()(decoded2)
decoded2 = PReLU()(decoded2)

decoded2x = Conv1D(filters=D2, kernel_size=kernel_size + 3, padding='same', name='d22')(decoded3_combined)
decoded2x = PReLU()(decoded2x)
decoded2x = concatenate([decoded2x, decoded2], axis=-1)
decoded2x = Dense(D2)(decoded2x)
decoded2x = PReLU()(decoded2x)

decoded2_combined = concatenate([decoded2x, skip2])

# Level 1
decoded1 = Conv1D(filters=D1, kernel_size=kernel_size, padding='same', name='d1')(decoded2_combined)
decoded1 = BatchNormalization()(decoded1)
decoded1 = PReLU()(decoded1)

decoded1x = Conv1D(filters=D1, kernel_size=kernel_size + 3, padding='same', name='d11')(decoded2_combined)
decoded1x = PReLU()(decoded1x)
decoded1x = concatenate([decoded1x, decoded1], axis=-1)
decoded1x = Dense(D1)(decoded1x)
decoded1x = PReLU()(decoded1x)

decoded1_combined = concatenate([decoded1x, skip1])

# Output
final_decoded = Conv1D(filters=INPUT_SIZE2 // 3, kernel_size=1, padding='same')(decoded1_combined)
final_decoded = Conv1D(filters=INPUT_SIZE2, kernel_size=1, padding='same')(final_decoded)
final_decoded = Flatten()(final_decoded)

# Build the model
autoencoder = Model(inputs=input_img, outputs=final_decoded)

# Compile the model
optimizer = Adam(learning_rate=0.01)
autoencoder.compile(optimizer=optimizer, loss='MSE')

# Summary of the model
autoencoder.summary()
# Out:
# Model parameters: D1=128, D2=32, D3=8, D4=4
# 2024-12-18 10:02:18.228263: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.228484: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.258341: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.258585: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.258772: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.258947: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.387178: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.387384: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.387559: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.387726: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.387889: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.388060: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.395328: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.395527: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.395709: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.395887: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.396075: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.396227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18440 MB memory:  -> device: 0, name: NVIDIA RTX A4500, pci bus id: 0000:2c:00.0, compute capability: 8.6
# 2024-12-18 10:02:18.396503: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-18 10:02:18.396648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 18306 MB memory:  -> device: 1, name: NVIDIA RTX A4500, pci bus id: 0000:41:00.0, compute capability: 8.6
# k size 1: 1
# k size 2: 1
# k size 1: 1
# k size 2: 1
# k size 1: 1
# k size 2: 1
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 576)]                0         []
#
#  tf.__operators__.getitem (  (None, 1, 576)               0         ['input_1[0][0]']
#  SlicingOpLambda)
#
#  e1 (Conv1D)                 (None, 1, 128)               221312    ['tf.__operators__.getitem[0][
#                                                                     0]']
#
#  e11 (Conv1D)                (None, 1, 128)               442496    ['tf.__operators__.getitem[0][
#                                                                     0]']
#
#  batch_normalization (Batch  (None, 1, 128)               512       ['e1[0][0]']
#  Normalization)
#
#  p_re_lu_1 (PReLU)           (None, 1, 128)               128       ['e11[0][0]']
#
#  p_re_lu (PReLU)             (None, 1, 128)               128       ['batch_normalization[0][0]']
#
#  concatenate (Concatenate)   (None, 1, 256)               0         ['p_re_lu_1[0][0]',
#                                                                      'p_re_lu[0][0]']
#
#  dense (Dense)               (None, 1, 128)               32896     ['concatenate[0][0]']
#
#  p_re_lu_2 (PReLU)           (None, 1, 128)               128       ['dense[0][0]']
#
#  e2 (Conv1D)                 (None, 1, 32)                12320     ['p_re_lu_2[0][0]']
#
#  e22 (Conv1D)                (None, 1, 32)                24608     ['p_re_lu_2[0][0]']
#
#  batch_normalization_1 (Bat  (None, 1, 32)                128       ['e2[0][0]']
#  chNormalization)
#
#  p_re_lu_4 (PReLU)           (None, 1, 32)                32        ['e22[0][0]']
#
#  p_re_lu_3 (PReLU)           (None, 1, 32)                32        ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  concatenate_1 (Concatenate  (None, 1, 64)                0         ['p_re_lu_4[0][0]',
#  )                                                                   'p_re_lu_3[0][0]']
#
#  dense_1 (Dense)             (None, 1, 32)                2080      ['concatenate_1[0][0]']
#
#  p_re_lu_5 (PReLU)           (None, 1, 32)                32        ['dense_1[0][0]']
#
#  e3 (Conv1D)                 (None, 1, 8)                 776       ['p_re_lu_5[0][0]']
#
#  e33 (Conv1D)                (None, 1, 8)                 1544      ['p_re_lu_5[0][0]']
#
#  batch_normalization_2 (Bat  (None, 1, 8)                 32        ['e3[0][0]']
#  chNormalization)
#
#  p_re_lu_7 (PReLU)           (None, 1, 8)                 8         ['e33[0][0]']
#
#  p_re_lu_6 (PReLU)           (None, 1, 8)                 8         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  concatenate_2 (Concatenate  (None, 1, 16)                0         ['p_re_lu_7[0][0]',
#  )                                                                   'p_re_lu_6[0][0]']
#
#  dense_2 (Dense)             (None, 1, 8)                 136       ['concatenate_2[0][0]']
#
#  p_re_lu_8 (PReLU)           (None, 1, 8)                 8         ['dense_2[0][0]']
#
#  reshape_6 (Reshape)         (None, 1, 8)                 0         ['p_re_lu_8[0][0]']
#
#  global_average_pooling1d_2  (None, 8)                    0         ['reshape_6[0][0]']
#   (GlobalAveragePooling1D)
#
#  reshape_7 (Reshape)         (None, 1, 8)                 0         ['global_average_pooling1d_2[0
#                                                                     ][0]']
#
#  conv1d_4 (Conv1D)           (None, 1, 1)                 8         ['reshape_7[0][0]']
#
#  d3 (Conv1D)                 (None, 1, 8)                 200       ['p_re_lu_8[0][0]']
#
#  tf.nn.relu_2 (TFOpLambda)   (None, 1, 1)                 0         ['conv1d_4[0][0]']
#
#  d33 (Conv1D)                (None, 1, 8)                 392       ['p_re_lu_8[0][0]']
#
#  batch_normalization_3 (Bat  (None, 1, 8)                 32        ['d3[0][0]']
#  chNormalization)
#
#  conv1d_5 (Conv1D)           (None, 1, 1)                 1         ['tf.nn.relu_2[0][0]']
#
#  p_re_lu_10 (PReLU)          (None, 1, 8)                 8         ['d33[0][0]']
#
#  p_re_lu_9 (PReLU)           (None, 1, 8)                 8         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  tf.math.sigmoid_2 (TFOpLam  (None, 1, 1)                 0         ['conv1d_5[0][0]']
#  bda)
#
#  concatenate_3 (Concatenate  (None, 1, 16)                0         ['p_re_lu_10[0][0]',
#  )                                                                   'p_re_lu_9[0][0]']
#
#  reshape_8 (Reshape)         (None, 1, 1, 1)              0         ['tf.math.sigmoid_2[0][0]']
#
#  reshape_3 (Reshape)         (None, 1, 32)                0         ['p_re_lu_5[0][0]']
#
#  dense_3 (Dense)             (None, 1, 8)                 136       ['concatenate_3[0][0]']
#
#  multiply_2 (Multiply)       (None, 1, 1, 8)              0         ['reshape_6[0][0]',
#                                                                      'reshape_8[0][0]']
#
#  global_average_pooling1d_1  (None, 32)                   0         ['reshape_3[0][0]']
#   (GlobalAveragePooling1D)
#
#  p_re_lu_11 (PReLU)          (None, 1, 8)                 8         ['dense_3[0][0]']
#
#  tf.compat.v1.squeeze_2 (TF  (None, 1, 8)                 0         ['multiply_2[0][0]']
#  OpLambda)
#
#  reshape_4 (Reshape)         (None, 1, 32)                0         ['global_average_pooling1d_1[0
#                                                                     ][0]']
#
#  concatenate_4 (Concatenate  (None, 1, 16)                0         ['p_re_lu_11[0][0]',
#  )                                                                   'tf.compat.v1.squeeze_2[0][0]
#                                                                     ']
#
#  conv1d_2 (Conv1D)           (None, 1, 1)                 32        ['reshape_4[0][0]']
#
#  d2 (Conv1D)                 (None, 1, 32)                1568      ['concatenate_4[0][0]']
#
#  tf.nn.relu_1 (TFOpLambda)   (None, 1, 1)                 0         ['conv1d_2[0][0]']
#
#  d22 (Conv1D)                (None, 1, 32)                3104      ['concatenate_4[0][0]']
#
#  batch_normalization_4 (Bat  (None, 1, 32)                128       ['d2[0][0]']
#  chNormalization)
#
#  conv1d_3 (Conv1D)           (None, 1, 1)                 1         ['tf.nn.relu_1[0][0]']
#
#  p_re_lu_13 (PReLU)          (None, 1, 32)                32        ['d22[0][0]']
#
#  p_re_lu_12 (PReLU)          (None, 1, 32)                32        ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  tf.math.sigmoid_1 (TFOpLam  (None, 1, 1)                 0         ['conv1d_3[0][0]']
#  bda)
#
#  concatenate_5 (Concatenate  (None, 1, 64)                0         ['p_re_lu_13[0][0]',
#  )                                                                   'p_re_lu_12[0][0]']
#
#  reshape_5 (Reshape)         (None, 1, 1, 1)              0         ['tf.math.sigmoid_1[0][0]']
#
#  reshape (Reshape)           (None, 1, 128)               0         ['p_re_lu_2[0][0]']
#
#  dense_4 (Dense)             (None, 1, 32)                2080      ['concatenate_5[0][0]']
#
#  multiply_1 (Multiply)       (None, 1, 1, 32)             0         ['reshape_3[0][0]',
#                                                                      'reshape_5[0][0]']
#
#  global_average_pooling1d (  (None, 128)                  0         ['reshape[0][0]']
#  GlobalAveragePooling1D)
#
#  p_re_lu_14 (PReLU)          (None, 1, 32)                32        ['dense_4[0][0]']
#
#  tf.compat.v1.squeeze_1 (TF  (None, 1, 32)                0         ['multiply_1[0][0]']
#  OpLambda)
#
#  reshape_1 (Reshape)         (None, 1, 128)               0         ['global_average_pooling1d[0][
#                                                                     0]']
#
#  concatenate_6 (Concatenate  (None, 1, 64)                0         ['p_re_lu_14[0][0]',
#  )                                                                   'tf.compat.v1.squeeze_1[0][0]
#                                                                     ']
#
#  conv1d (Conv1D)             (None, 1, 1)                 128       ['reshape_1[0][0]']
#
#  d1 (Conv1D)                 (None, 1, 128)               24704     ['concatenate_6[0][0]']
#
#  tf.nn.relu (TFOpLambda)     (None, 1, 1)                 0         ['conv1d[0][0]']
#
#  d11 (Conv1D)                (None, 1, 128)               49280     ['concatenate_6[0][0]']
#
#  batch_normalization_5 (Bat  (None, 1, 128)               512       ['d1[0][0]']
#  chNormalization)
#
#  conv1d_1 (Conv1D)           (None, 1, 1)                 1         ['tf.nn.relu[0][0]']
#
#  p_re_lu_16 (PReLU)          (None, 1, 128)               128       ['d11[0][0]']
#
#  p_re_lu_15 (PReLU)          (None, 1, 128)               128       ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  tf.math.sigmoid (TFOpLambd  (None, 1, 1)                 0         ['conv1d_1[0][0]']
#  a)
#
#  concatenate_7 (Concatenate  (None, 1, 256)               0         ['p_re_lu_16[0][0]',
#  )                                                                   'p_re_lu_15[0][0]']
#
#  reshape_2 (Reshape)         (None, 1, 1, 1)              0         ['tf.math.sigmoid[0][0]']
#
#  dense_5 (Dense)             (None, 1, 128)               32896     ['concatenate_7[0][0]']
#
#  multiply (Multiply)         (None, 1, 1, 128)            0         ['reshape[0][0]',
#                                                                      'reshape_2[0][0]']
#
#  p_re_lu_17 (PReLU)          (None, 1, 128)               128       ['dense_5[0][0]']
#
#  tf.compat.v1.squeeze (TFOp  (None, 1, 128)               0         ['multiply[0][0]']
#  Lambda)
#
#  concatenate_8 (Concatenate  (None, 1, 256)               0         ['p_re_lu_17[0][0]',
#  )                                                                   'tf.compat.v1.squeeze[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 1, 192)               49344     ['concatenate_8[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 1, 576)               111168    ['conv1d_6[0][0]']
#
#  flatten (Flatten)           (None, 576)                  0         ['conv1d_7[0][0]']
#
# ==================================================================================================
# Total params: 1015563 (3.87 MB)
# Trainable params: 1014891 (3.87 MB)
# Non-trainable params: 672 (2.62 KB)
# __________________________________________________________________________________________________

# %%
# Training Parameters
epochs = 50
batch_size = 1024

# Early stopping and model checkpoint callbacks
es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)
mc = ModelCheckpoint(
    filepath=f'{model_path}German_model_{file_name}_p{w1}_s{z1}_drop_{drop_rate}_ep{epochs}.h5',
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

# Timing the training process
start_time = time.time()

# Model training
history = autoencoder.fit(
    data_noise_selected,
    data_noise_selected,
    epochs=epochs,
    batch_size=batch_size,
    shuffle=True,
    verbose=1,
    validation_split=0.1,
    callbacks=[es, mc]
)

# End timing and print training duration
end_time = time.time()
print(f"Training time for German data: {end_time - start_time:.4f} seconds")
# Out:
# Epoch 1/50
# 2024-12-18 10:02:23.038879: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-12-18 10:02:24.264764: I external/local_xla/xla/service/service.cc:168] XLA service 0x76d074cd7fc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-18 10:02:24.264778: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A4500, Compute Capability 8.6
# 2024-12-18 10:02:24.264784: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA RTX A4500, Compute Capability 8.6
# 2024-12-18 10:02:24.268051: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734505344.320009  229784 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 25/25 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 1: loss improved from inf to 0.00353, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 13s 158ms/step - loss: 0.0035 - val_loss: 0.0049
# Epoch 2/50
#  1/25 [>.............................] - ETA: 0s - loss: 9.6072e-04
# /home/g202321530/anaconda3/envs/tf/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 25/25 [==============================] - ETA: 0s - loss: 9.5986e-04
# Epoch 2: loss improved from 0.00353 to 0.00096, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 26ms/step - loss: 9.5986e-04 - val_loss: 0.0049
# Epoch 3/50
# 25/25 [==============================] - ETA: 0s - loss: 9.0885e-04
# Epoch 3: loss improved from 0.00096 to 0.00091, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 32ms/step - loss: 9.0885e-04 - val_loss: 0.0049
# Epoch 4/50
# 25/25 [==============================] - ETA: 0s - loss: 8.9044e-04
# Epoch 4: loss improved from 0.00091 to 0.00089, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 8.9044e-04 - val_loss: 0.0048
# Epoch 5/50
# 25/25 [==============================] - ETA: 0s - loss: 8.6955e-04
# Epoch 5: loss improved from 0.00089 to 0.00087, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 28ms/step - loss: 8.6955e-04 - val_loss: 0.0046
# Epoch 6/50
# 25/25 [==============================] - ETA: 0s - loss: 8.5239e-04
# Epoch 6: loss improved from 0.00087 to 0.00085, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 28ms/step - loss: 8.5239e-04 - val_loss: 0.0045
# Epoch 7/50
# 25/25 [==============================] - ETA: 0s - loss: 8.4316e-04
# Epoch 7: loss improved from 0.00085 to 0.00084, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 28ms/step - loss: 8.4316e-04 - val_loss: 0.0043
# Epoch 8/50
# 25/25 [==============================] - ETA: 0s - loss: 8.4047e-04
# Epoch 8: loss improved from 0.00084 to 0.00084, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 27ms/step - loss: 8.4047e-04 - val_loss: 0.0043
# Epoch 9/50
# 24/25 [===========================>..] - ETA: 0s - loss: 8.3948e-04
# Epoch 9: loss improved from 0.00084 to 0.00084, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 24ms/step - loss: 8.3839e-04 - val_loss: 0.0042
# Epoch 10/50
# 25/25 [==============================] - ETA: 0s - loss: 8.3295e-04
# Epoch 10: loss improved from 0.00084 to 0.00083, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 8.3295e-04 - val_loss: 0.0042
# Epoch 11/50
# 25/25 [==============================] - ETA: 0s - loss: 8.3172e-04
# Epoch 11: loss improved from 0.00083 to 0.00083, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 30ms/step - loss: 8.3172e-04 - val_loss: 0.0041
# Epoch 12/50
# 25/25 [==============================] - ETA: 0s - loss: 8.2593e-04
# Epoch 12: loss improved from 0.00083 to 0.00083, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 8.2593e-04 - val_loss: 0.0037
# Epoch 13/50
# 25/25 [==============================] - ETA: 0s - loss: 8.0597e-04
# Epoch 13: loss improved from 0.00083 to 0.00081, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 28ms/step - loss: 8.0597e-04 - val_loss: 0.0036
# Epoch 14/50
# 25/25 [==============================] - ETA: 0s - loss: 7.9250e-04
# Epoch 14: loss improved from 0.00081 to 0.00079, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 27ms/step - loss: 7.9250e-04 - val_loss: 0.0036
# Epoch 15/50
# 25/25 [==============================] - ETA: 0s - loss: 7.8868e-04
# Epoch 15: loss improved from 0.00079 to 0.00079, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 7.8868e-04 - val_loss: 0.0036
# Epoch 16/50
# 25/25 [==============================] - ETA: 0s - loss: 7.7384e-04
# Epoch 16: loss improved from 0.00079 to 0.00077, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 7.7384e-04 - val_loss: 0.0034
# Epoch 17/50
# 25/25 [==============================] - ETA: 0s - loss: 7.7254e-04
# Epoch 17: loss improved from 0.00077 to 0.00077, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 27ms/step - loss: 7.7254e-04 - val_loss: 0.0034
# Epoch 18/50
# 25/25 [==============================] - ETA: 0s - loss: 7.6115e-04
# Epoch 18: loss improved from 0.00077 to 0.00076, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 27ms/step - loss: 7.6115e-04 - val_loss: 0.0032
# Epoch 19/50
# 25/25 [==============================] - ETA: 0s - loss: 7.6903e-04
# Epoch 19: loss did not improve from 0.00076
# 25/25 [==============================] - 1s 23ms/step - loss: 7.6903e-04 - val_loss: 0.0035
# Epoch 20/50
# 25/25 [==============================] - ETA: 0s - loss: 7.7417e-04
# Epoch 20: loss did not improve from 0.00076
# 25/25 [==============================] - 1s 25ms/step - loss: 7.7417e-04 - val_loss: 0.0032
# Epoch 21/50
# 25/25 [==============================] - ETA: 0s - loss: 7.5119e-04
# Epoch 21: loss improved from 0.00076 to 0.00075, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 7.5119e-04 - val_loss: 0.0031
# Epoch 22/50
# 25/25 [==============================] - ETA: 0s - loss: 7.3592e-04
# Epoch 22: loss improved from 0.00075 to 0.00074, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 7.3592e-04 - val_loss: 0.0030
# Epoch 23/50
# 25/25 [==============================] - ETA: 0s - loss: 7.4555e-04
# Epoch 23: loss did not improve from 0.00074
# 25/25 [==============================] - 1s 25ms/step - loss: 7.4555e-04 - val_loss: 0.0033
# Epoch 24/50
# 25/25 [==============================] - ETA: 0s - loss: 7.3225e-04
# Epoch 24: loss improved from 0.00074 to 0.00073, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 7.3225e-04 - val_loss: 0.0028
# Epoch 25/50
# 23/25 [==========================>...] - ETA: 0s - loss: 7.1531e-04
# Epoch 25: loss improved from 0.00073 to 0.00072, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 26ms/step - loss: 7.1569e-04 - val_loss: 0.0026
# Epoch 26/50
# 25/25 [==============================] - ETA: 0s - loss: 7.0596e-04
# Epoch 26: loss improved from 0.00072 to 0.00071, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 28ms/step - loss: 7.0596e-04 - val_loss: 0.0026
# Epoch 27/50
# 25/25 [==============================] - ETA: 0s - loss: 7.0539e-04
# Epoch 27: loss improved from 0.00071 to 0.00071, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 7.0539e-04 - val_loss: 0.0027
# Epoch 28/50
# 23/25 [==========================>...] - ETA: 0s - loss: 7.0078e-04
# Epoch 28: loss improved from 0.00071 to 0.00070, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 26ms/step - loss: 7.0257e-04 - val_loss: 0.0026
# Epoch 29/50
# 25/25 [==============================] - ETA: 0s - loss: 6.9849e-04
# Epoch 29: loss improved from 0.00070 to 0.00070, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 27ms/step - loss: 6.9849e-04 - val_loss: 0.0025
# Epoch 30/50
# 25/25 [==============================] - ETA: 0s - loss: 6.9879e-04
# Epoch 30: loss did not improve from 0.00070
# 25/25 [==============================] - 1s 22ms/step - loss: 6.9879e-04 - val_loss: 0.0024
# Epoch 31/50
# 25/25 [==============================] - ETA: 0s - loss: 6.9610e-04
# Epoch 31: loss improved from 0.00070 to 0.00070, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 6.9610e-04 - val_loss: 0.0024
# Epoch 32/50
# 25/25 [==============================] - ETA: 0s - loss: 6.9784e-04
# Epoch 32: loss did not improve from 0.00070
# 25/25 [==============================] - 1s 25ms/step - loss: 6.9784e-04 - val_loss: 0.0024
# Epoch 33/50
# 25/25 [==============================] - ETA: 0s - loss: 7.0506e-04
# Epoch 33: loss did not improve from 0.00070
# 25/25 [==============================] - 1s 22ms/step - loss: 7.0506e-04 - val_loss: 0.0033
# Epoch 34/50
# 25/25 [==============================] - ETA: 0s - loss: 7.5147e-04
# Epoch 34: loss did not improve from 0.00070
# 25/25 [==============================] - 1s 25ms/step - loss: 7.5147e-04 - val_loss: 0.0024
# Epoch 35/50
# 25/25 [==============================] - ETA: 0s - loss: 6.8232e-04
# Epoch 35: loss improved from 0.00070 to 0.00068, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 28ms/step - loss: 6.8232e-04 - val_loss: 0.0023
# Epoch 36/50
# 25/25 [==============================] - ETA: 0s - loss: 6.6926e-04
# Epoch 36: loss improved from 0.00068 to 0.00067, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 28ms/step - loss: 6.6926e-04 - val_loss: 0.0020
# Epoch 37/50
# 25/25 [==============================] - ETA: 0s - loss: 6.6524e-04
# Epoch 37: loss improved from 0.00067 to 0.00067, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 28ms/step - loss: 6.6524e-04 - val_loss: 0.0020
# Epoch 38/50
# 25/25 [==============================] - ETA: 0s - loss: 6.6174e-04
# Epoch 38: loss improved from 0.00067 to 0.00066, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 6.6174e-04 - val_loss: 0.0020
# Epoch 39/50
# 23/25 [==========================>...] - ETA: 0s - loss: 6.6182e-04
# Epoch 39: loss did not improve from 0.00066
# 25/25 [==============================] - 1s 23ms/step - loss: 6.6204e-04 - val_loss: 0.0020
# Epoch 40/50
# 25/25 [==============================] - ETA: 0s - loss: 6.6130e-04
# Epoch 40: loss improved from 0.00066 to 0.00066, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 27ms/step - loss: 6.6130e-04 - val_loss: 0.0019
# Epoch 41/50
# 25/25 [==============================] - ETA: 0s - loss: 6.6244e-04
# Epoch 41: loss did not improve from 0.00066
# 25/25 [==============================] - 1s 23ms/step - loss: 6.6244e-04 - val_loss: 0.0019
# Epoch 42/50
# 25/25 [==============================] - ETA: 0s - loss: 6.5256e-04
# Epoch 42: loss improved from 0.00066 to 0.00065, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 28ms/step - loss: 6.5256e-04 - val_loss: 0.0019
# Epoch 43/50
# 25/25 [==============================] - ETA: 0s - loss: 6.4802e-04
# Epoch 43: loss improved from 0.00065 to 0.00065, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 28ms/step - loss: 6.4802e-04 - val_loss: 0.0019
# Epoch 44/50
# 25/25 [==============================] - ETA: 0s - loss: 6.5173e-04
# Epoch 44: loss did not improve from 0.00065
# 25/25 [==============================] - 1s 24ms/step - loss: 6.5173e-04 - val_loss: 0.0017
# Epoch 45/50
# 25/25 [==============================] - ETA: 0s - loss: 6.3485e-04
# Epoch 45: loss improved from 0.00065 to 0.00063, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 6.3485e-04 - val_loss: 0.0017
# Epoch 46/50
# 25/25 [==============================] - ETA: 0s - loss: 6.3296e-04
# Epoch 46: loss improved from 0.00063 to 0.00063, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 6.3296e-04 - val_loss: 0.0017
# Epoch 47/50
# 25/25 [==============================] - ETA: 0s - loss: 6.3445e-04
# Epoch 47: loss did not improve from 0.00063
# 25/25 [==============================] - 1s 24ms/step - loss: 6.3445e-04 - val_loss: 0.0017
# Epoch 48/50
# 24/25 [===========================>..] - ETA: 0s - loss: 6.3223e-04
# Epoch 48: loss improved from 0.00063 to 0.00063, saving model to ./model/German_model_slice_german_1_p24_s6_drop_0.2_ep50.h5
# 25/25 [==============================] - 1s 24ms/step - loss: 6.3163e-04 - val_loss: 0.0016
# Epoch 49/50
# 25/25 [==============================] - ETA: 0s - loss: 6.3195e-04
# Epoch 49: loss did not improve from 0.00063
# 25/25 [==============================] - 1s 23ms/step - loss: 6.3195e-04 - val_loss: 0.0017
# Epoch 50/50
# 25/25 [==============================] - ETA: 0s - loss: 6.3309e-04
# Epoch 50: loss did not improve from 0.00063
# 25/25 [==============================] - 1s 22ms/step - loss: 6.3309e-04 - val_loss: 0.0016
# Training time for German data: 45.8235 seconds
